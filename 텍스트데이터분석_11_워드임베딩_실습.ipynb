# %% [markdown]
# # 영화 리뷰 워드 임베딩 (Word2Vec, FastText)
# - gensim 라이브러리 사용 : pip install gensim
#     - Word2Vec : models.Word2Vec
#     - FastText : models.FastText

# %% [markdown]
# ## 1. 데이터 준비
# * 토큰화가 잘 되어 있는 filtered 데이터 사용

# %%
import pandas as pd
data_filename = './data/Korean_movie_reviews_2016_filtered.csv'
data_df = pd.read_csv(data_filename)
data_df.head()
# Out:
#                                               review  rate
# 0                           아니 딴 그렇 비 비탄 총 대체 왜 들 온겨     7
# 1      진심 쓰레기 영화 만들 무서 알 쫄아 틀었 이건 뭐 웃 거리 없는 쓰레기 영화 임     1
# 2  역대 좀비 영화 가장 최고다 원작 만화 읽어 보려 영화 보고 결정 하려 감독 간츠 ...    10
# 3                                     온종일 불편한 피 범벅 일     6
# 4    답답함 극치 움직일 잇으 좀 움직여 어지간히 좀비 봣으 얼 타고 때려 잡 때 되 않냐     1

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788189 entries, 0 to 788188
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   review  785448 non-null  object
#  1   rate    788189 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 12.0+ MB

# %%
# 결측치 제거 (rate에 결측치)
# 결측치를 제거하지 않으면 review 데이터 추출 시 float으로 타입 변환됨
data_df.dropna(inplace=True)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785448 entries, 0 to 788188
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   review  785448 non-null  object
#  1   rate    785448 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 18.0+ MB

# %%
# review만 모아서 review별 토큰 리스트로 변환
review_list = list(data_df.review)
review_list[:5]
# Out:
# ['아니 딴 그렇 비 비탄 총 대체 왜 들 온겨',
#  '진심 쓰레기 영화 만들 무서 알 쫄아 틀었 이건 뭐 웃 거리 없는 쓰레기 영화 임',
#  '역대 좀비 영화 가장 최고다 원작 만화 읽어 보려 영화 보고 결정 하려 감독 간츠 실사 했 사람 거르려 그냥 봤 정말 흠잡 없는 최고 좀비 영화 잔인 거 싫어하지 참고 볼 만하 로미 인물 왜 그런 모르',
#  '온종일 불편한 피 범벅 일',
#  '답답함 극치 움직일 잇으 좀 움직여 어지간히 좀비 봣으 얼 타고 때려 잡 때 되 않냐']

# %%
type(review_list[0])
# Out:
# str

# %%
token_list = [review.split() for review in review_list]
print(token_list[:2])
# Out:
# [['아니', '딴', '그렇', '비', '비탄', '총', '대체', '왜', '들', '온겨'], ['진심', '쓰레기', '영화', '만들', '무서', '알', '쫄아', '틀었', '이건', '뭐', '웃', '거리', '없는', '쓰레기', '영화', '임']]

# %% [markdown]
# ## 1. Word2Vec 활용 영화 리뷰 워드 임베딩
# * https://radimrehurek.com/gensim/models/word2vec.html

# %% [markdown]
# ### Skipgram, negative=10 인 경우

# %%
# Word2Vec 모델 생성 및 학습 : window=3, min_count=3
from gensim.models import Word2Vec, FastText

model_sg_n10 = Word2Vec(token_list, vector_size=100, window=3, min_count=3, sg=1, negative=10)
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %%
# 단어의 임베딩 벡터 확인
model_sg_n10.wv['이정재']
# Out:
# array([-0.30131823, -0.25093555,  0.01621621, -0.29339746, -0.07493659,
#         0.03348006,  0.24109828,  0.17003949,  1.0170791 , -0.3725296 ,
#         0.01386617, -0.38653138, -0.08693989,  0.38460654, -0.24476591,
#        -0.13096347,  0.0550114 ,  0.26178092,  0.16558614, -0.15305355,
#         0.09905244,  0.15917975,  0.25912958,  0.03980461, -0.2786992 ,
#        -0.69742554,  0.09255859, -0.1204332 , -0.02523373, -0.5827989 ,
#         0.1923586 ,  0.27499023, -0.01320179, -0.04431716, -0.12922384,
#        -0.39832488, -0.47781035, -0.01463354, -0.40494347, -0.35644382,
#        -0.44496304,  0.26329848, -0.2721873 , -0.21406436,  0.00602711,
#         0.05851013, -0.09316395, -0.16491286, -0.48209107, -0.12088627,
#         0.12374502, -0.605039  ,  0.04546161, -0.29217416, -0.06029905,
#         0.0162137 ,  0.28312585, -0.00921892,  0.1773466 , -0.09854253,
#        -0.33123663,  0.16552547,  0.66964346, -0.25429425, -0.51240504,
#        -0.41291025,  0.09548771, -0.3791562 ,  0.19796747, -0.02480338,
#         0.42776537,  0.00883668, -0.14240491,  0.4941912 ,  0.1528065 ,
#        -0.17900254,  0.21988145, -0.08545233, -0.553675  , -0.03119645,
#        -0.08212699,  0.18163174, -0.14298688,  0.19612975,  0.5763991 ,
#        -0.30950552, -0.15362768, -0.0250649 ,  0.37689978,  0.38629165,
#         0.83744234,  0.40858728,  0.77581865, -0.07825498,  0.40861207,
#         0.09459121,  0.02035779,  0.41086578,  0.15590836,  0.62986887],
#       dtype=float32)

# %%
# 단어의 임베딩 벡터 차원 확인
len(model_sg_n10.wv['이정재'])
# Out:
# 100

# %%
# 두 단어 간 유사도 확인
wv = model_sg_n10.wv
wv.similarity('이정재', '송강호')
# Out:
# np.float32(0.82303834)

# %%
# 특정 단어와 유사한 단어 추출
wv.most_similar('이정재', topn=20)
# Out:
# [('이범수', 0.8375040292739868),
#  ('공유', 0.8237292766571045),
#  ('송강호', 0.8230383992195129),
#  ('김범수', 0.7944673299789429),
#  ('정우성', 0.7810684442520142),
#  ('박해일', 0.7600818276405334),
#  ('조재현', 0.7532915472984314),
#  ('김남길', 0.7351386547088623),
#  ('이성민', 0.7342302203178406),
#  ('곽도원', 0.7320489883422852),
#  ('이병헌', 0.7230488657951355),
#  ('주지훈', 0.7211538553237915),
#  ('김명민', 0.7189921140670776),
#  ('마동석', 0.718457043170929),
#  ('김윤석', 0.712743878364563),
#  ('이진욱', 0.7108944654464722),
#  ('김성균', 0.7061110138893127),
#  ('조진웅', 0.7048090696334839),
#  ('정재형', 0.7018560171127319),
#  ('송광호', 0.7004767060279846)]

# %%
print([word for word, _ in wv.most_similar('재밌', topn=50)])
# Out:
# ['재미있', '재밌네', '재밌었', '잼남', '재밌어', '재밋음', '재밋엇어용', '잼슴', '재밋엇음', '재밋어용', '재밋는듯', '재밌아', '재밌슴', '재밋게봣', '재밋엇', '재미있었', '재밋네용', '쟈밋', '재밋었어', '재미있네', '재미있더', '존잼임', '재밋었음', '잼난', '재밋었습니', '재밋엇어', '엇', '재밌더', '재밋게봣습니', '잼잇엇음', '재밌던', '재밋습니', '재밋구', '재밋게봣어', '꿀잼임', '재밋네', '재밋어', '재밌엇습니', '존잼', '재밋습', '재밌드', '재밌고', '쟀', '재미있아', '재밋습니당', '재미있겠', '재밋당', '꾸르잼', '재밋게봄', '개꿀잼']

# %% [markdown]
# ### Skipgram, negative=5 인 경우

# %%
# 모델 생성
model_sg_n5 = Word2Vec(token_list, vector_size=100, window=3, min_count=3, sg=1, negative=5)

# %%
# 특어 단어와 유사한 단어 추출 : 이정재
wv = model_sg_n5
wv.most_similar('이정재', topn=20)

# %%
# 특어 단어와 유사한 단어 추출 : 재밌
print([word for word, _ in wv.most_similar('재밌', topn=50)])

# %% [markdown]
# ### CBOW, negative=10 인 경우

# %%
model_cbow_n10 = Word2Vec(token_list, vector_size=100, window=3, min_count=3, sg=0, negative=10)
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %%
wv = model_cbow_n10.wv
wv.most_similar('이정재', topn=20)
# Out:
# [('이범수', 0.79250168800354),
#  ('김윤석', 0.757521390914917),
#  ('이성민', 0.7521887421607971),
#  ('조재현', 0.7223163843154907),
#  ('송강호', 0.7136583924293518),
#  ('공유', 0.7135612964630127),
#  ('김범수', 0.705906331539154),
#  ('박해일', 0.6941290497779846),
#  ('김남길', 0.6905163526535034),
#  ('주지훈', 0.6892768144607544),
#  ('이진욱', 0.6836351156234741),
#  ('엄지원', 0.6753150820732117),
#  ('차승원', 0.6722527742385864),
#  ('송광호', 0.6698824167251587),
#  ('곽도원', 0.6538428068161011),
#  ('남자배우', 0.6440716981887817),
#  ('김영애', 0.6440244913101196),
#  ('배성우', 0.6414062976837158),
#  ('민호', 0.6394912600517273),
#  ('김성오', 0.6350715160369873)]

# %%
print([word for word, _ in wv.most_similar('재밌', topn=50)])
# Out:
# ['재미있', '재밌네', '재밌어', '재밌었', '재밋음', '잼남', '재미있었', '재밌는', '재밋어', '재미있네', '재밌더', '재미있어', '재밌던', '재밋엇어', '재밋네', '재밋엇', '꿀잼', '재밋', '재밋었어', '재밌고', '재밋었', '재밌다', '재미있던', '재밋엇음', '재밌구', '재미있는', '웃김', '재밌게', '잼', '재미있다', '재밋었음', '재미있고', '재밋습니', '존잼', '재미있더', '재밌겠', '개꿀잼', '재밌으', '괜찮', '웃겼', '재미있게', '재미나', '무서웠', '재밋어용', '재밋었습니', '재밋엇습니', '꿀잼임', '멋있', '재미있구', '핵꿀잼']

# %% [markdown]
# ### CBOW, negative=5 인 경우

# %%
model_cbow_n5 = Word2Vec(token_list, vector_size=100, window=3, min_count=3, sg=0, negative=5)

# %%
wv = model_cbow_n5.wv
wv.most_similar('이정재', topn=20)

# %%
print([word for word, _ in wv.most_similar('재밌', topn=50)])

# %% [markdown]
# ### OOV(Out of Vocabulary) 문제

# %%
# corpus에 없는 단어 확인 : 우주평화 
'우주평화' in model_sg_n10.wv.key_to_index
# Out:
# False

# %%
# corpus에 없는 단어의 임베딩 벡터 확인 
model_sg_n10.wv['우주평화']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 # corpus에 없는 단어의 임베딩 벡터 확인
# ----> 2 model_sg_n10.wv['우주평화']
#
# File c:\Users\user\anaconda3\envs\textmine26\lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File c:\Users\user\anaconda3\envs\textmine26\lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File c:\Users\user\anaconda3\envs\textmine26\lib\site-packages\gensim\models\keyedvectors.py:420, in KeyedVectors.get_index(self, key, default)
#     418     return default
#     419 else:
# --> 420     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key '우주평화' not present"

# %% [markdown]
# ## 2. FastText 활용 영화 리뷰 워드 임베딩
# * https://radimrehurek.com/gensim/models/fasttext.html

# %%
# FastText 모델 생성 및 학습
# window=3, min_count=3, min_n=2, max_n=2
from gensim.models import FastText
model = FastText(token_list, vector_size=100, window=3, min_count=3, sg=1, negative=10, min_n=2, max_n=2)
wv = model.wv
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %%
# 특정 단어와 유사한 단어 추출 : 이정재
wv.most_similar('이정재', topn=20)
# Out:
# [('이범수', 0.8481776118278503),
#  ('정재영', 0.823732316493988),
#  ('정재형', 0.8154134750366211),
#  ('정재', 0.8150242567062378),
#  ('공유', 0.8132644295692444),
#  ('김범수', 0.8087623119354248),
#  ('송강호', 0.8012228608131409),
#  ('정우성', 0.7848514318466187),
#  ('박해일', 0.780883252620697),
#  ('임성민', 0.7780024409294128),
#  ('김철민', 0.7639382481575012),
#  ('김윤아', 0.7618164420127869),
#  ('조재현', 0.7578012347221375),
#  ('이진욱', 0.7557739019393921),
#  ('강호', 0.7550739645957947),
#  ('김동석', 0.751789391040802),
#  ('김지민', 0.7509211301803589),
#  ('김성균', 0.7504815459251404),
#  ('임완', 0.7497298717498779),
#  ('김준호', 0.7485611438751221)]

# %%
# corpus에 없는 단어 확인 : 우주평화 
'우주평화' in wv.key_to_index
# Out:
# False

# %%
# corpus에 없는 단어의 임베딩 벡터 확인 
wv['우주평화']
# Out:
# array([ 0.23017994, -0.03935279,  0.02040762,  0.14700837,  0.07471496,
#        -0.00636202, -0.28314894,  0.69687533,  0.5012603 ,  0.2830396 ,
#        -0.13376804,  0.20334467,  0.0823907 ,  0.21367574, -0.25869495,
#        -0.36317283, -0.00768335, -0.23155436,  0.21612136,  0.27791545,
#         0.18160741, -0.0312101 ,  0.0627465 ,  0.12420802,  0.17137076,
#         0.0680049 , -0.45257998, -0.33062345, -0.05223049, -0.24585667,
#         0.09283717, -0.28918225,  0.4160947 , -0.38824463, -0.07534844,
#         0.23207572,  0.06192512,  0.13819161, -0.18563665, -0.0381081 ,
#        -0.24077196, -0.0454542 , -0.26211286,  0.03645729, -0.01869273,
#         0.09730145, -0.02429619,  0.04831687, -0.11244973,  0.126141  ,
#         0.36447155,  0.1589127 , -0.13443096, -0.14153995,  0.00888285,
#        -0.06307435,  0.17641549,  0.39612976, -0.10228705,  0.30450672,
#         0.11985805,  0.35375875, -0.49301416, -0.18263409, -0.20507929,
#        -0.31490976, -0.22344145,  0.02301068,  0.03775267,  0.23831503,
#        -0.16226058,  0.05495359,  0.24343094, -0.00276791, -0.03638268,
#         0.2686544 , -0.06910191, -0.19113562, -0.22988686, -0.08960028,
#        -0.36772028, -0.49196887,  0.04304175,  0.24428996,  0.20671448,
#         0.07623961, -0.24550977,  0.31794864,  0.19415657,  0.09339909,
#        -0.15228306,  0.60625666, -0.38627428, -0.09988377, -0.07135076,
#         0.5179616 , -0.28136593, -0.22955947, -0.24657759,  0.27569538],
#       dtype=float32)

# %%
# corpus에 없는 단어와 유사한 단어추출 
wv.most_similar('우주평화', topn=20)
# Out:
# [('우주', 0.8280603289604187),
#  ('우주비행사', 0.8143617510795593),
#  ('우장', 0.809966504573822),
#  ('평화', 0.8086783289909363),
#  ('회색곰', 0.7986518740653992),
#  ('켤', 0.7958736419677734),
#  ('투명인간', 0.7901362180709839),
#  ('격동', 0.7884229421615601),
#  ('우방', 0.784814715385437),
#  ('지구대', 0.7839534282684326),
#  ('산화', 0.7838135957717896),
#  ('쉘', 0.7837761044502258),
#  ('우주여행', 0.7833935618400574),
#  ('아비규환', 0.7829169631004333),
#  ('위기탈출넘버원', 0.7814899682998657),
#  ('지구촌', 0.780367374420166),
#  ('산전수전', 0.7803260087966919),
#  ('포동포동', 0.7782886028289795),
#  ('꽃밭', 0.7774452567100525),
#  ('봉화', 0.777400016784668)]
